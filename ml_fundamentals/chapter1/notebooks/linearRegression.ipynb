# %% [markdown]
# ### importing the main lib for this course

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json , os , joblib , pathlib

# %% [markdown]
# #### importing the lib for this session

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor 
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### load the models config and some helper function

# %%
config = json.load(open('../configs/regression.json'))
base_path = pathlib.Path.cwd().parent.parent.parent
base_path
# Out:
# PosixPath('/home/aloha-zkaria/Hands-on-AI-Tutorial')

# %%
def load_dataset(path):
    """
    Args: path
    return : dataframe of the dataset
    """
    print(base_path/path)
    if not not os.path.exists(base_path / path):
        raise FileNotFoundError(f"{path} not found")
    return pd.read_csv(path)

# %%
def detect_target(df):
    """fallback: last column"""
    return df.columns[-1]

# %% [markdown]
# #### loads the dataset and begin

# %%
df = load_dataset(config["datasets"][1]["path"])
# Out:
# /home/aloha-zkaria/Hands-on-AI-Tutorial/ml_fundamentals/chapter1/data/Life Expectancy Data.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df = load_dataset(config["datasets"][1]["path"])
#
# Cell In[42], line 8, in load_dataset(path)
#       6 print(base_path/path)
#       7 if not not os.path.exists(base_path / path):
# ----> 8     raise FileNotFoundError(f"{path} not found")
#       9 return pd.read_csv(path)
#
# FileNotFoundError: ml_fundamentals/chapter1/data/Life Expectancy Data.csv not found

# %%
numeric_cols = df.select_dtypes(include="number").columns

if len(numeric_cols) > 0:
    # Histograms
    df[numeric_cols].hist(figsize=(12, 8))
    plt.suptitle(f"{name} - Histograms")
    plt.show()

    # Boxplot
    df[numeric_cols].plot(kind="box", figsize=(12, 6))
    plt.title(f"{name} - Boxplot")
    plt.show()

    # Correlation heatmap (basic)
    plt.imshow(df.corr(numeric_only=True))
    plt.colorbar()
    plt.title(f"{name} - Correlation Heatmap")
    plt.show()

else:
    print("⚠️ No numeric columns to plot.")
