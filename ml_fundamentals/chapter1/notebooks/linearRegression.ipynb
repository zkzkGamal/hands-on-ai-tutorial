# %% [markdown]
# ### importing the main lib for this course

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json , os , joblib

# %% [markdown]
# ### importing the lib for this
